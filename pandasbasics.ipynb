# %% [markdown]
# Pandas

# %%
import pandas as pd
# why pandas?
# -flexibility of python 
# -working with big data
df = pd.read_csv('pokemon_data.csv')
#read_excel for xlsx file 
#tab seperated file delimiter='\t' (any thing that seperating the data)
# print (df.head(3))

# %% [markdown]
# reading data form file

# %%
#read headers
# print(df.columns)

#read each col
# print(df[['Name' , 'Type 1']][0:5])

#read each row
# print(df.iloc[0:4])
# for index, row in df.iterrows():
#     print(index,row['Name'])
# df.loc[df['Type 1']=="Fire"] # cool 

#read a specific location (r,c)
# print(df.iloc[2,1])

# %% [markdown]
# sortin/describing data

# %%
# df.describe() #cool
df.sort_values(['Type 1','HP'], ascending = [1,0]) #first ascending and second descending
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# df.head(5)
# df['Total'] = df['HP'] + df['Attack']+ df['Defense']
# df = df.drop(columns=['Total'])

df['Total'] =  df.iloc[:,4:10].sum(axis=1)
cols = list(df.columns)
# df = df[['Total','HP','Defense']]
df = df[cols[0:4]+[cols[-1]]+cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# saving out data frame

# %%
# df.to_csv('modified.csv',index = False)
# df.to_excel('modified.xlsx',index = False)
# df.to_csv('modified.txt', index=False ,sep=';')

# %% [markdown]
# Filtering Data

# %%
# new_df = df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')]

# new_df = new_df.reset_index(drop=True) #inplace = true for not using of new_df

# df.loc[-df['Name'].str.contains('Mega')]

import  re 

# df.loc[df['Type 1'].str.contains('fire|grass' , flags=re.I , regex = True)]
# df.loc[df['Name'].str.contains('pi[a-z]*' , flags=re.I , regex = True)] # only pi containing elements
# Out:
#        #                     Name    Type 1    Type 2  Total   HP  Attack  \
# 13    10                 Caterpie       Bug       NaN    195   45      30
# 20    16                   Pidgey    Normal    Flying    251   40      45
# 21    17                Pidgeotto    Normal    Flying    349   63      60
# 22    18                  Pidgeot    Normal    Flying    479   83      80
# 23    18      PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25                  Pikachu  Electric       NaN    320   35      55
# 42    37                   Vulpix      Fire       NaN    299   38      41
# 76    70               Weepinbell     Grass    Poison    390   65      90
# 84    78                 Rapidash      Fire       NaN    500   65     100
# 136  127                   Pinsir       Bug       NaN    500   65     125
# 137  127        PinsirMega Pinsir       Bug    Flying    600   65     155
# 181  167                 Spinarak       Bug    Poison    250   40      60
# ...

# %% [markdown]
# conditional changes

# %%
df.loc[df['Type 1'] == 'Fire' , 'Type 1'] = 'Flamer' #one changes to another cool

# %%
# df.loc[df['Total'] > 500 , ['Generation' , 'Legendary']] = ['Test 1', 'Test 2']

# %% [markdown]
# Aggregate Statistics (groupby)

# %%
# Group by 'Type 1' and calculate the mean only for numeric columns
# df.groupby(['Type 1']).mean(numeric_only=True).sort_values('HP',ascending=False) # mean sum count ... many more 

df['count'] = 1

df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# Working with large amounts of data

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.csv' , chunksize=5):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results])

new_df
# Out:
#          # Name Type 1 Type 2 Total HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire     1    1    NaN      0     1  1      1       1       1       1     1
# Grass    4    4    NaN      4     4  4      4       4       4       4     4
# Fire     4    4    NaN      3     4  4      4       4       4       4     4
# Water    1    1    NaN      0     1  1      1       1       1       1     1
# Bug      2    2    NaN      0     2  2      2       2       2       2     2
# ...     ..  ...    ...    ...   ... ..    ...     ...     ...     ...   ...
# Fairy    1    1    NaN      0     1  1      1       1       1       1     1
# Flying   2    2    NaN      2     2  2      2       2       2       2     2
# Fire     1    1    NaN      1     1  1      1       1       1       1     1
# Psychic  2    2    NaN      2     2  2      2       2       2       2     2
# Rock     2    2    NaN      2     2  2      2       2       2       2     2
#
#         Generation Legendary
# ...
