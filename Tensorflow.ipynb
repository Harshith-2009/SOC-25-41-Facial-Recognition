# %% [markdown]
# #### Tensorflow

# %% [markdown]
# 1. Building tensorflow churn model
# 2. training and predicting
# 3. saving your model and reloding

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Churn.csv')

# %%
X = pd.get_dummies(df.drop(['Churn', 'Customer ID'], axis = 1))
y = df['Churn'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = .2 )

# %%
X_train.head()
# Out:
#       Senior Citizen  tenure  Monthly Charges  Gender_Female  Gender_Male  \
# 3710               0       1            50.75          False         True
# 6853               0      44            61.90          False         True
# 3505               0      68            19.95          False         True
# 5304               0      43            40.45          False         True
# 727                0      22            26.25           True        False
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# 3710        True        False           True           False
# 6853       False         True          False            True
# 3505       False         True          False            True
# 5304        True        False          False            True
# 727         True        False           True           False
#
#       Phone Service_No  ...  Total Charges_995.35  Total Charges_996.45  \
# 3710             False  ...                 False                 False
# ...

# %%
y_train.head()
# Out:
# 3710    0
# 6853    0
# 3505    0
# 5304    0
# 727     0
# Name: Churn, dtype: int64

# %% [markdown]
# 1. Import dependencies
# 2. Build and compile model
# 3. Fit, Predict and Evaluate
# 4. Saving and Reloding

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %%
model = Sequential() # instantiating sequential class
# we are adding bunch of layers for out neural networks 
# two hidden layers
# first one has 32 neurons and second one has 64 neurons with relu activation
model.add(Dense(units=32, activation='relu', input_dim=len(X_train.columns))) 
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
# Out:
# C:\Users\kvasa\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=200, batch_size=32)
# Out:
# Epoch 1/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7505 - loss: 0.5242
# Epoch 2/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7666 - loss: 0.4902
# Epoch 3/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7807 - loss: 0.4804
# Epoch 4/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7692 - loss: 0.4817
# Epoch 5/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7786 - loss: 0.4769
# Epoch 6/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7762 - loss: 0.4753
# Epoch 7/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7853 - loss: 0.4622
# Epoch 8/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7898 - loss: 0.4602
# Epoch 9/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7888 - loss: 0.4719
# Epoch 10/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7910 - loss: 0.4571
# Epoch 11/200
# ...

# %%
y_hat = model.predict(X_test)
y_hat = [0 if val < 0.5 else 1 for val in y_hat]
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.7970191625266146

# %%
model.save('tfmodel.keras')
