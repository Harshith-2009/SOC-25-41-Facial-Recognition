# %% [markdown]
# # matplotlib

# %%
#basics
#load necessary libs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#always check out documentation for interesting stuff

# %% [markdown]
# ## Basic graph

# %%
x = [0,1,2,3,4,5]
y = [0,2,4,6,8,10]

#resize your graph
plt.figure(figsize=(6,3), dpi = 300)

#line 1
plt.plot(x, y , label = '2x' , c = 'orange', linewidth = 3 , linestyle = '--')

plt.title('Our First Graph', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20}) # title has font dict too
# adding label

#creating a second line 
x2 = np.arange(0,6.0,0.5)

plt.plot(x2,x2**2, 'r' , label = 'x^2') #you can divide curve based on array 

plt.xlabel('X axis') # same dict thing too labels too
plt.ylabel('Y axis')

#you can change x axis tick marks 
plt.yticks([0,4,8])
#save graph plt.savefig('mygrapg.png', dpi = select)

#adding fig legends 
plt.legend()

#show plot
plt.show() # get rid of that line ..

# %%
#bar charts
labels = ['A','B','C']
values = [5,6,9]

bars = plt.bar(labels,values)
# set hatch
bars[0].set_hatch('/')
bars[1].set_hatch('*')

plt.show()
